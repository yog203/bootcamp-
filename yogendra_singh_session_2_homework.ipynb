# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4ba0c0e-9861-471d-ac46-3698044d63cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4ba0c0e-9861-471d-ac46-3698044d63cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

print(df.head())
# Out:
#    student_id   name  age     city  math  science  english  \
# 0         101  Aarav   16   Mumbai    78       84       69
# 1         102   Diya   16    Delhi    91       88       94
# 2         103  Kabir   17  Mathura    55       61       58
# 3         104  Meera   16    Noida    72       79       81
# 4         105  Rohan   17   Mumbai    40       52       47
#
#    attendance_percent  study_hours_per_week  assignments_submitted  \
# 0                  92                     8                      9
# 1                  96                    11                     10
# 2                  75                     5                      6
# 3                  89                     7                      8
# 4                  68                     3                      5
#
#    final_project_score
# 0                   82
# 1                   93
# 2                   60
# 3                   78
# 4                   45

# %%
df["final_project_score"].mean()
# Out:
# np.float64(73.65)

# %%
df[df["study_hours_per_week"] > 8]
# Out:
#     student_id    name  age   city  math  science  english  \
# 1          102    Diya   16  Delhi    91       88       94
# 5          106    Sara   16  Delhi    88       93       90
# 7          108  Ananya   16  Noida    95       92       89
# 9          110    Tara   16  Delhi    83       76       85
# 13         114   Priya   16  Delhi    89       86       91
# 15         116    Riya   16  Noida    92       90       96
# 17         118   Aditi   16  Delhi    80       85       83
#
#     attendance_percent  study_hours_per_week  assignments_submitted  \
# 1                   96                    11                     10
# 5                   97                    10                     10
# 7                   94                    12                     10
# 9                   90                     9                      9
# 13                  95                    10                     10
# 15                  98                    13                     10
# ...

# %%
df["average_marks"] = (df["math"] + df["science"] + df["english"]) / 3

df.groupby("city")["average_marks"].mean()
# Out:
# city
# Delhi      86.800000
# Mathura    59.066667
# Mumbai     56.200000
# Noida      83.333333
# Name: average_marks, dtype: float64

# %%
def   performance(avg):
    if    avg >= 80:
        return "Excellent"
    elif  avg >= 60:
        return "Good"
    else:
        return "Poor"

df ["average_marks"] = ( df["math"] + df["science"] + df["english"] ) / 3
df ["performance_level" ] = df ["average_marks"].apply (performance)

df [["name", "average_marks", "performance_level"]]
# Out:
#       name  average_marks performance_level
# 0    Aarav      77.000000              Good
# 1     Diya      91.000000         Excellent
# 2    Kabir      58.000000              Poor
# 3    Meera      77.333333              Good
# 4    Rohan      46.333333              Poor
# 5     Sara      90.333333         Excellent
# 6   Ishaan      66.666667              Good
# 7   Ananya      92.000000         Excellent
# 8   Vivaan      52.000000              Poor
# 9     Tara      81.333333         Excellent
# 10   Arjun      67.333333              Good
# 11   Nisha      78.000000              Good
# 12     Dev      40.666667              Poor
# 13   Priya      88.666667         Excellent
# 14   Kunal      57.333333              Poor
# 15    Riya      92.666667         Excellent
# 16      Om      65.000000              Good
# 17   Aditi      82.666667         Excellent
# 18    Yash      46.000000              Poor
# 19   Sneha      76.666667              Good

# %%
df.to_csv(
    "selected_students.csv",
    index=False,
    columns=["name", "city", "average_marks", "performance_level"]
)

# %%
from google.colab import files
files.download("selected_students.csv")

# %%
df = pd.read_csv("selected_students.csv")

# %%
df
# Out:
#       name     city  average_marks performance_level
# 0    Aarav   Mumbai      77.000000              Good
# 1     Diya    Delhi      91.000000         Excellent
# 2    Kabir  Mathura      58.000000              Poor
# 3    Meera    Noida      77.333333              Good
# 4    Rohan   Mumbai      46.333333              Poor
# 5     Sara    Delhi      90.333333         Excellent
# 6   Ishaan  Mathura      66.666667              Good
# 7   Ananya    Noida      92.000000         Excellent
# 8   Vivaan   Mumbai      52.000000              Poor
# 9     Tara    Delhi      81.333333         Excellent
# 10   Arjun  Mathura      67.333333              Good
# 11   Nisha    Noida      78.000000              Good
# 12     Dev   Mumbai      40.666667              Poor
# 13   Priya    Delhi      88.666667         Excellent
# 14   Kunal  Mathura      57.333333              Poor
# 15    Riya    Noida      92.666667         Excellent
# 16      Om   Mumbai      65.000000              Good
# ...

# %%
college={
    "name":"Naman Parashar",
    "college_name":"GLA UNIVERSITY",
    "section":"CB",
    "grades":'A',
    "city":"Mathura"
}
info={
    "name":"Aman Usmani",
    "college_name":"GLA UNIVERSITY",
    "section":"CB",
    "grades":"A+",
    "city":"Mathura"
}
info2={
    "name":"Deepak Mittal",
    "college_name":"GLA UNIVERSITY",
    "section":"CB",
    "grades":"A+",
    "city":"Mathura"
}

# %%
marks = 72

if marks>=40:
  print("Pass")
else:
  print("Fail")
# Out:
# Pass

# %%
marks=50
if(marks>=80):
  print("distinction")
elif(marks>=40 or marks<=79):
  print("pass")
# Out:
# pass

# %%
marks=51
if(marks%2==0):
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
age=56
if(age<13):
  print("child")
elif(age>=13 and age<19):
  print("teenager")
else:
   print("old")
# Out:
# old

# %%
students = [
    {"name": "Naman", "marks": 92, "attendance": 95, "lab_assignment": True},
    {"name": "Aman", "marks": 95, "attendance": 100, "lab_assignment": True},
    {"name": "Deepak", "marks": 58, "attendance": 60, "lab_assignment": True},
    {"name": "Akash", "marks": 88, "attendance": 90, "lab_assignment": False},
    {"name": "Bhanu", "marks": 35, "attendance": 80, "lab_assignment": True}
]

for student in students:
    if student["lab_assignment"] == False:
        result = "Lab Assignment Not Submitted"
    elif student["attendance"] < 75:
        result = "Low Attendance"
    elif student["marks"] >= 70:
        result = "Distinction"
    elif student["marks"] >= 40:
        result = "Pass"
    else:
        result = "Fail"

    print(student["name"], "-", result)
# Out:
# Naman - Distinction
# Aman - Distinction
# Deepak - Low Attendance
# Akash - Lab Assignment Not Submitted
# Bhanu - Fail

# %%
import pandas as pd

students_df = pd.DataFrame(students)
display(students_df.head())
# Out:
#      name  marks  attendance  lab_assignment
# 0   Naman     92          95            True
# 1    Aman     95         100            True
# 2  Deepak     58          60            True
# 3   Akash     88          90           False
# 4   Bhanu     35          80            True

# %%
display(students_df.describe())
# Out:
#            marks  attendance
# count   5.000000    5.000000
# mean   73.600000   85.000000
# std    26.159128   15.811388
# min    35.000000   60.000000
# 25%    58.000000   80.000000
# 50%    88.000000   90.000000
# 75%    92.000000   95.000000
# max    95.000000  100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='name', y='marks', data=students_df, palette='viridis')
plt.title('Student Marks Distribution')
plt.xlabel('Student Name')
plt.ylabel('Marks')
plt.ylim(0, 100) # Assuming marks are out of 100
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_3897/233503054.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='name', y='marks', data=students_df, palette='viridis')

# %%
failed_assignments = students_df[students_df['lab_assignment'] == False]
print("Students who failed to submit their lab assignment:")
for name in failed_assignments['name']:
    print(name)
# Out:
# Students who failed to submit their lab assignment:
# Akash

# %%
submitted_assignments_df = students_df[students_df['lab_assignment'] == True]
average_attendance_submitted = submitted_assignments_df['attendance'].mean()
print(f"Average attendance for students who submitted their lab assignment: {average_attendance_submitted:.2f}%")
# Out:
# Average attendance for students who submitted their lab assignment: 83.75%

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='attendance', y='marks', data=students_df, hue='lab_assignment', s=100, alpha=0.8)
plt.title('Marks vs. Attendance')
plt.xlabel('Attendance (%)')
plt.ylabel('Marks')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
students_below_40_marks = students_df[students_df['marks'] < 40]
print("Students with marks below 40:")
if not students_below_40_marks.empty:
    for name in students_below_40_marks['name']:
        print(name)
else:
    print("No students found with marks below 40.")
# Out:
# Students with marks below 40:
# Bhanu

# %%
plt.figure(figsize=(10, 6))
sns.histplot(students_df['marks'], bins=5, kde=True, color='skyblue')
plt.title('Distribution of Student Marks')
plt.xlabel('Marks')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
correlation = students_df['marks'].corr(students_df['attendance'])
print(f"Correlation coefficient between Marks and Attendance: {correlation:.2f}")
# Out:
# Correlation coefficient between Marks and Attendance: 0.70

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Prepare the data
X = students_df['attendance'].values.reshape(-1, 1) # Independent variable (attendance)
y = students_df['marks'].values # Dependent variable (marks)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Print the coefficients
print(f"Intercept: {model.intercept_:.2f}")
print(f"Coefficient for Attendance: {model.coef_[0]:.2f}")
# Out:
# Intercept: -25.00
# Coefficient for Attendance: 1.16

# %%
r_squared = model.score(X, y)
print(f"R-squared value: {r_squared:.2f}")
# Out:
# R-squared value: 0.49

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='attendance', y='marks', data=students_df, hue='lab_assignment', s=100, alpha=0.8)

# Plot the regression line
plt.plot(X, model.predict(X), color='red', linestyle='--', linewidth=2, label=f'Regression Line (R^2 = {r_squared:.2f})')

plt.title('Marks vs. Attendance with Regression Line')
plt.xlabel('Attendance (%)')
plt.ylabel('Marks')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(submitted_assignments_df['marks'], bins=5, kde=True, color='lightgreen')
plt.title('Distribution of Marks for Students with Submitted Lab Assignments')
plt.xlabel('Marks')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.histplot(submitted_assignments_df['attendance'], bins=5, kde=True, color='blue', label='Submitted Assignments', alpha=0.6)
sns.histplot(failed_assignments['attendance'], bins=5, kde=True, color='red', label='Missed Assignments', alpha=0.6)
plt.title('Attendance Distribution: Submitted vs. Missed Lab Assignments')
plt.xlabel('Attendance (%)')
plt.ylabel('Number of Students')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Re-defining students and students_df for self-contained execution
students = [
    {"name": "Naman", "marks": 92, "attendance": 95, "lab_assignment": True},
    {"name": "Aman", "marks": 95, "attendance": 100, "lab_assignment": True},
    {"name": "Deepak", "marks": 58, "attendance": 60, "lab_assignment": True},
    {"name": "Akash", "marks": 88, "attendance": 90, "lab_assignment": False},
    {"name": "Bhanu", "marks": 35, "attendance": 80, "lab_assignment": True}
]
students_df = pd.DataFrame(students)

plt.figure(figsize=(8, 6))
sns.boxplot(x='lab_assignment', y='marks', data=students_df, palette='pastel')
plt.title('Comparison of Marks Based on Lab Assignment Submission')
plt.xlabel('Lab Assignment Submitted (True/False)')
plt.ylabel('Marks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_3897/1229102047.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='lab_assignment', y='marks', data=students_df, palette='pastel')

# %%
students_above_90_marks = students_df[students_df['marks'] > 90]
print("Students who scored above 90 marks:")
if not students_above_90_marks.empty:
    for name in students_above_90_marks['name']:
        print(name)
else:
    print("No students found with marks above 90.")
# Out:
# Students who scored above 90 marks:
# Naman
# Aman
